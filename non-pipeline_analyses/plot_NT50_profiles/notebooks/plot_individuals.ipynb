# %% [markdown]
# # Plot NT50 profiles for individually-run sera

# %%
# Import packages
import os
import altair as alt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import gmean


# Ignore error message from Altair about large dataframes
_ = alt.data_transformers.disable_max_rows()

# %%
# Basic color palette
color_palette = [
    '#345995', #blue
    '#03cea4', #teal
    '#ca1551', #red
    '#eac435', #yellow
               ]

# %%
# Define inputs
datadir = '../data'
resultsdir = '../results'
os.makedirs(datadir, exist_ok = True)
os.makedirs(resultsdir, exist_ok = True)

# Define SCH titers
SCH_titers = (pd.read_csv('../../../results/aggregated_titers/titers_SCH.csv')
             .assign(
                 barcode = lambda x: x['serum'].str.split('_').str[2],)
             )

# Define Penn titers
titers_PennVaccineCohort = (pd.read_csv('../../../results/aggregated_titers/titers_PennVaccineCohort.csv')
                            .assign(
                                barcode = lambda x: x['serum'].str.split('_').str[2],
                                timepoint = lambda x: 'd' + x['serum'].str.split('d').str[1])
                           )

# Define Australian MA22 vaccine cohort titers
Australia_MA22_titers = (pd.read_csv('../../../results/aggregated_titers/titers_AusVaccineCohort.csv')
                         .assign(
                             barcode = lambda x: x['serum'].str.split('_').str[1],
                             timepoint = lambda x: x['serum'].str.split('_').str[2])
                        )

# Define sera metadata
SCH_metadata = pd.read_csv('../../../data/sera_metadata/metadata_SCH.csv')
AusVaccineCohort_metadata = (pd.read_csv('../../../data/sera_metadata/metadata_AusVaccineCohort.csv')
                             .rename(columns = {'Bloom_lab_serum_ID': 'serum'}))
# Reformatting the Penn metadata
day0 = (pd.read_csv('../../../data/sera_metadata/metadata_PennVaccineCohort.csv')
        .drop(['Bloom_lab_ID_d28'], axis=1)
        .rename(columns = {'Bloom_lab_ID_d0': 'serum'}))

day28 = (pd.read_csv('../../../data/sera_metadata/metadata_PennVaccineCohort.csv')
         .drop(['Bloom_lab_ID_d0'], axis=1)
         .rename(columns = {'Bloom_lab_ID_d28': 'serum'}))
PennVaccineCohort_metadata = pd.concat([day0,day28])
# Concatenate all metadata
all_metadata = pd.concat([SCH_metadata,PennVaccineCohort_metadata, AusVaccineCohort_metadata])


# Concatenate all titers into one dataframe
all_titers = pd.concat([
    SCH_titers,
    titers_PennVaccineCohort,
    Australia_MA22_titers
])

# Merge all titers and metadata on 'serum' key
all_titers = all_titers.merge(all_metadata, on = 'serum')

# Add a slightly more informative 'group_detail' column that incorporates pre- or post-vax info
all_titers['group_detail'] = np.where(all_titers['group'] == 'SCH', 
                                         all_titers['group'],  # If the value matches the string
                                         all_titers['group'].astype(str) + '_' + all_titers['timepoint'])  # Otherwise, combination of col2 and col3

all_titers

# %%
# Define virus order
viral_plot_order = pd.read_csv('../../../data/H3N2library_2023-2024_strain_order.csv')
virus_order = [v for v in viral_plot_order.strain]

# Define vaccine strains
vaccine_strains = []
with open('../data/vaccine_strains.csv') as f:
    for line in f:
        line = line.strip('\n')
        if 'strain' not in line:
            vaccine_strains.append(line)

# Define separate list where Massachusetts/18/2022 is reclassified as a 2023-circulating strains
vaccine_strains_no_Massachusetts = [item for item in vaccine_strains if item != 'A/Massachusetts/18/2022']

# %% [markdown]
# ## Make toy NT50 plot for overview figure

# %%
# Configure
color_scheme = alt.Color('serum', title = 'serum', legend=None).scale(scheme='greys')
titer_range = [30, 16000]
titleFontSize=19
labelFontSize=19
width = 200
height = 220

four_special_viruses = [
    'A/Krabi/THIS050/2023',
    'A/Ontario/RV00796/2023',
    'A/Bangkok/P3755/2023',
    'A/Massachusetts/18/2022',
]

four_special_viruses_labelColors = {
    'condition': [
        {'test' : 'datum.label == "A/Massachusetts/18/2022"', 'value': color_palette[2]},
        {'test' : 'datum.label == "A/Krabi/THIS050/2023"', 'value': color_palette[0]},
        {'test' : 'datum.label == "A/Bangkok/P3755/2023"', 'value': color_palette[1]},
        {'test' : 'datum.label == "A/Ontario/RV00796/2023"', 'value': color_palette[3]},
    ],
     'value': 'grey'} # The default value if no condition is met


data = (SCH_titers[SCH_titers['virus'].isin(four_special_viruses)]
        .query('serum == "SCH23_y2009_s007"')
       )

# Make plot
line = (alt.Chart(data, width=width, height=height)
        .mark_line(size = 5, point = False)
        .encode(
            alt.X('virus', 
                      axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                                      labelColor = four_special_viruses_labelColors,
                                      labelFontWeight = 'bold',
                                      title = None, titleY = 330,
                                      labelAlign = 'right',labelLimit = 1000, labelAngle=310), 
                      sort = four_special_viruses
                     ),
            alt.Y('titer', 
                      scale = alt.Scale(type='log', domain=titer_range, nice=False), 
                      axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title='neutralization titer')
                 ),
            color = color_scheme,
        )
       )

points = (alt.Chart(data, width=width)
          .mark_point(size = 120, stroke='black', strokeWidth=2, filled=True)
          .encode(
              alt.X('virus', sort = four_special_viruses),
              alt.Y('titer'),
              color = color_scheme
          )
         )
    

layered = alt.layer(line, points).properties(title=''
                                            ).configure_title(fontSize=labelFontSize)



# Save
outfile = os.path.join(resultsdir, 'toy_nt50_plot.svg')
layered.save(outfile, dpi = 600)
layered

# %% [markdown]
# ## Make nice individual sera plots
# For those individuals with more interesting neutralization profiles.

# %%
def plot_individual_sera(data):
    """ Function for plotting individual sera in different panels """

    # Configure
    color_scheme = alt.Color('serum', title = 'serum', legend=None).scale(range=color_palette)
    titer_range = [40, 16000]
    titleFontSize=19
    labelFontSize=19
    width = 1300
    height = 180

    markerSize = 150
    

    # Make plot
    line = (alt.Chart(data, width=width, height=height)
            .mark_line(size = 5, point = False)
            .encode(
                alt.X('virus', 
                          axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                                          title = None, titleY = 330,labelAlign = 'right',labelLimit = 1000), 
                          sort = virus_order
                         ),
                alt.Y('titer', 
                          scale = alt.Scale(type='log', domain=titer_range, nice=False), 
                          axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title='neutralization titer')
                     ),
                color = color_scheme,
            )
           )
    
    points = (alt.Chart(data, width=width)
              .mark_point(size = markerSize, stroke='black', strokeWidth=2, filled=True)
              .encode(
                  alt.X('virus', sort = virus_order),
                  alt.Y('titer'),
                  color = color_scheme
              )
             )
        
    
    layered = (alt.layer(line, points)
               .facet(row = alt.Row('serum'))
               .properties(title='')
               .configure_title(fontSize=labelFontSize)
               .configure_header(
                   labels=False, # Removing labels for pretty versions of figure, comment out to see labels
                   title=None, labelFontSize=labelFontSize, labelFontWeight='bold', 
                   labelOrient='right', labelAngle=0, labelAnchor='start', labelAlign='right')
              )

    return layered

# %%
# Identify specific sera to plot and their age and sex
sera_to_plot_dict = {
    'SCH23_y2009_s007': '14-year-old',
    'PENN23_y1999_s048_d0': '24-year-old'
}

# Subset data to just circulting strains
data = all_titers[~all_titers['virus'].isin(vaccine_strains_no_Massachusetts)]

# Subset data to just sera of interest
data = data[data['serum'].isin(list(sera_to_plot_dict.keys()))]

# Replace serum IDs with more informative metadata
data = data.replace({'serum': sera_to_plot_dict})


# Produce and save final plot
plot = plot_individual_sera(data)
outfile = os.path.join(resultsdir, 'individual_example_profile.svg')
plot.save(outfile, dpi = 600)
plot

# %% [markdown]
# ## Make individual line plots and median dot plots for US-based pediatric and adult pre-vaccination cohorts

# %%
# Define group fine dictionary
group_detail_dict = {'SCH': 'Children (n=56)',
                   'PennVaccineCohort_d0': 'Adults pre-vaccination (n=39)',
                   'PennVaccineCohort_28': 'Adults post-vaccination (n=39)'}

group_sort_list = ['SCH', 'PennVaccineCohort_d0', 'PennVaccineCohort_d28', 'MA22VaccineCohort_prevax', 'MA22VaccineCohort_postvax',]

# %%
# Make plot with all individuals and median dots
color_scheme = alt.Color('group_detail', 
                         title = 'Cohort', 
                         sort=group_sort_list,
                         legend=None
                        ).scale(range=color_palette)
titer_range = [30, 16000]
titleFontSize=19
labelFontSize=19
lineOpacity = 0.2
lineSize = 2.8
markerOpacity = 0.9
markerSize = 160
width = 1300
height = 280

# Get data
cohorts_to_plot = ['SCH', 'PennVaccineCohort_d0']
data = all_titers[all_titers['group_detail'].isin(cohorts_to_plot)]
data = (data[~data['virus'].isin(vaccine_strains_no_Massachusetts)]
        .replace({'group_detail': group_detail_dict})
       )



line = (alt.Chart(data, width = width,height=height)
        .mark_line(size = lineSize, point = False, opacity = lineOpacity)
        .encode(
            alt.X('virus', 
                      axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                                      title = None,labelLimit = 1000, labelAlign = 'right',
                                      # labelColor = all_vacc_label_colors,labelFontWeight = all_vacc_label_weights,
                                     ),             
                      sort = virus_order
                     ),
            alt.Y('titer', 
                      scale =alt.Scale(type='log',domain=titer_range, nice=False), 
                      axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title="neutralization titer")
                 ),
            detail = 'serum',
            color = color_scheme,
            # order = 'virus_order'
        )
       )

points = (alt.Chart(data, width=width)
          .mark_point(size = markerSize,
                      stroke = 'black',
                      strokeWidth = 2.2,
                      filled=True, 
                      opacity=markerOpacity)
          .encode(
              alt.X('virus', sort = virus_order),
              alt.Y('median(titer)'),
              color = color_scheme,
          )
         )
    
layered = (alt.layer(line, points)
           .facet(
               row = alt.Row('group_detail:N', sort = group_sort_list, 
                             title = None,
                             # header=None
                            ),
               config = alt.Config(
                        legend = alt.LegendConfig(titleFontSize=titleFontSize, labelFontSize = labelFontSize,
                            strokeColor='gray',padding=10,cornerRadius=10,
                            labelLimit = 1000 # Let legend labels be as long as they want
                        )
                       )
           ).configure_header(
                   labels=False, # Removing labels for pretty versions of figure, comment out to see labels
                              labelFontSize=labelFontSize,labelFontWeight='bold',
                              labelOrient='right', labelAngle=0, labelAnchor='start', labelAlign='right')
)


# Save final plot
outfile = os.path.join(resultsdir, 'cohort_individuals_and_medians.svg')
layered.save(outfile, dpi = 600)
layered

# %% [markdown]
# ## Plot individuals as a heatmap

# %%
# Configure
titleFontSize=14
labelFontSize=14

width = 1000
height = 1200

# Get data
cohorts_to_plot = ['SCH', 'PennVaccineCohort_d0']
data = (all_titers[all_titers['group_detail'].isin(cohorts_to_plot)]
        .replace({'group_detail': group_detail_dict})
        .query('serum != "SCH23_y2021_s057"')
       )
# data = (data[~data['virus'].isin(vaccine_strains_no_Massachusetts)]
#         .replace({'group_detail': group_detail_dict})
#        )


age_ordered_sera = data[['serum','year_of_birth']].drop_duplicates().sort_values(by='year_of_birth', ascending=False).serum.tolist()


# Heatmap base code
heatmap = alt.Chart(data).mark_rect().encode(
    x=alt.X('virus:O', sort=virus_order, title='HA from virus strain',
            axis = alt.Axis(titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                            title=None,labelLimit = 1000, labelAlign = 'right')),
    y=alt.Y('serum:O', sort=age_ordered_sera, title='sera',
            axis = alt.Axis(titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                           titleFontWeight = 'normal')),
    color=alt.Color('titer:Q',
                    scale=alt.Scale(type='log', scheme='purples'),
                    title='neutralization titer',
                    legend=alt.Legend(
                        labelFontSize=labelFontSize,
                        titleFontSize=titleFontSize,

        )),
    tooltip=['virus', 'serum', 'titer']
).properties(
    width=width,
    height=height
)


# Save final plot
outfile = os.path.join(resultsdir, 'cohort_individuals_heatmap.svg')
heatmap.save(outfile, dpi = 600)

heatmap

# %% [markdown]
# ## Does S145N alter J subclade virus antigenicity? Does this differ between cohorts?
# To answer, plot titers against 145N and 145S-containing J subclade strains only.

# %%
nextclade_df = pd.read_csv('../../draw_trees/data/nextclade.csv', sep = ';',)
j_subclade_strains = nextclade_df.query('subclade == "J"').seqName.str.replace('_', '').to_list()
j_subclade_strains

# %%
# Make plot with all individuals and median dots
color_scheme = alt.Color('group_detail', 
                         title = 'Cohort', 
                         sort=group_sort_list,
                         legend=None
                        ).scale(range=color_palette)
titer_range = [30, 16000]
titleFontSize=19
labelFontSize=19
lineOpacity = 0.3
lineSize = 2.8
markerOpacity = 0.8
markerSize = 150
width = 260
height = 260

# Get data
cohorts_to_plot = ['SCH', 'PennVaccineCohort_d0']
data = all_titers[all_titers['group_detail'].isin(cohorts_to_plot)]

# Function to determine S145N strain 
def mut_function(row):
   if row['virus'] == 'A/Krabi/THIS050/2023':
      return '145N'
   if row['virus'] == 'A/Saskatchewan/SKFLU317847/2023':
      return '145N'
   if row['virus'] == 'A/Sydney/710/2023':
      return '145N'
   return '145S'
data['position_145'] = data.apply(mut_function, axis=1) # add if strain contains 145N or not

# Only plot J subclade strains
data = (data[data['virus'].isin(j_subclade_strains)] 
        # Add other details
        .replace({'group_detail': group_detail_dict})
        .assign(year_of_birth = lambda x: x['serum'].str.split('_').str[1])
        .query('serum != "SCH23_y2021_s057"')
        [['serum', 'position_145', 'titer', 'group_detail']]
        .drop_duplicates()
        .query('serum == "SCH23_y2009_s001"')
       )


points = (alt.Chart(data, width=width)
          .mark_point(size = markerSize,
                      stroke = 'black',
                      strokeWidth = 2,
                      filled=True, 
                      opacity=markerOpacity)
          .encode(
              alt.X('position_145', axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize)),
              alt.Y('mean(titer):Q', scale = alt.Scale(type='log',domain=titer_range, nice=False),
                    axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title="NT50")),
              tooltip = ['serum'],
              detail='serum',
              color = color_scheme,
              xOffset="jitter:Q",
              
          ).interactive().transform_calculate(
        # Generate Gaussian jitter with a Box-Muller transform
        jitter="sqrt(-4*log(random()))*cos(2*PI*random())"
    )
         )
    
layered = (alt.layer(points)
           .facet(
               row = alt.Row('group_detail:N', sort = group_sort_list, title = None,
                            ),
               config = alt.Config(
                        legend = alt.LegendConfig(titleFontSize=titleFontSize, labelFontSize = labelFontSize,
                            strokeColor='gray',padding=10,cornerRadius=10,
                            labelLimit = 1000 # Let legend labels be as long as they want
                        )
                       )
           ).configure_header(labelFontSize=labelFontSize,labelFontWeight='bold',
                              labelOrient='right', labelAngle=0, labelAnchor='start', labelAlign='right')
)


# Save final plot
outfile = os.path.join(resultsdir, 'kids.png')
# layered.save(outfile, dpi = 600)
layered

# %% [markdown]
# ## Plot pre- and post-vaccination

# %%
# Make plot with median and IQR for vaccine groups on same axis

# Configure
color_palette = [
    '#345995', #blue
    '#03cea4', #teal
    '#ca1551', #red
    '#eac435', #yellow
               ]

color_scheme = alt.Color('group_detail', 
                         title = 'Cohort', 
                         sort=group_sort_list,
                         legend=None
                        ).scale(range=color_palette[2:])
titer_range = [30, 16000]
titleFontSize=19
labelFontSize=19
lineOpacity = 0.4
lineSize = 4
width = 1000
height = 240

# Get data
cohorts_to_plot = ['AusVaccineCohort']
data = all_titers[all_titers['group'].isin(cohorts_to_plot)]
data = (data[~data['virus'].isin(vaccine_strains_no_Massachusetts)]
        # .replace({'group_detail': group_fine_dict})
       
       )



line = (alt.Chart(data, width = width,height=height)
        .mark_line(size = lineSize, point = False, opacity = lineOpacity)
        .encode(
            alt.X('virus', 
                      axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                                      title = None,labelLimit = 1000, labelAlign = 'right',
                                      # labelColor = all_vacc_label_colors,labelFontWeight = all_vacc_label_weights,
                                     ),             
                      sort = virus_order
                     ),
            alt.Y('titer', 
                      scale =alt.Scale(type='log',domain=titer_range, nice=False), 
                      axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title="NT50")
                 ),
            detail = 'serum',
            color = color_scheme,
            tooltip = ['serum']
        )
       )

points = (alt.Chart(data, width=width)
          .mark_point(size = 120,
                      stroke = 'black',
                      strokeWidth = 2,
                      filled=True)
          .encode(
              alt.X('virus', sort = virus_order),
              alt.Y('median(titer)'),
              color = color_scheme
          )
         )
    
layered = (alt.layer(line, points)
           .facet(
               row = alt.Row('group_detail:N', sort = group_sort_list, 
                             title = None,
                             # header=None
                            ),
               config = alt.Config(
                        legend = alt.LegendConfig(titleFontSize=titleFontSize, labelFontSize = labelFontSize,
                            strokeColor='gray',padding=10,cornerRadius=10,
                            labelLimit = 1000 # Let legend labels be as long as they want
                        )
                       )
           ).configure_header(labelFontSize=labelFontSize,
                              labelFontWeight='bold',
                             labelOrient = 'top')
)

layered

# %%
# Make plot with median and IQR for vaccine groups on same axis

# Configure
color_palette = [
    '#345995', #blue
    '#03cea4', #teal
    '#ca1551', #red
    '#eac435', #yellow
               ]

color_scheme = alt.Color('group_detail', 
                         title = 'Cohort', 
                         sort=group_sort_list,
                         legend=None
                        ).scale(range=color_palette[2:])
titer_range = [30, 16000]
titleFontSize=19
labelFontSize=19
lineOpacity = 0.4
lineSize = 4
width = 1000
height = 240

# Get data
cohorts_to_plot = ['PennVaccineCohort']
data = all_titers[all_titers['group'].isin(cohorts_to_plot)]
data = (data[~data['virus'].isin(vaccine_strains_no_Massachusetts)]
        # .replace({'group_detail': group_fine_dict})
       
       )



line = (alt.Chart(data, width = width,height=height)
        .mark_line(size = lineSize, point = False, opacity = lineOpacity)
        .encode(
            alt.X('virus', 
                      axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                                      title = None,labelLimit = 1000, labelAlign = 'right',
                                      # labelColor = all_vacc_label_colors,labelFontWeight = all_vacc_label_weights,
                                     ),             
                      sort = virus_order
                     ),
            alt.Y('titer', 
                      scale =alt.Scale(type='log',domain=titer_range, nice=False), 
                      axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title="NT50")
                 ),
            detail = 'serum',
            color = color_scheme,
            tooltip = ['serum']
        ).interactive()
       )

points = (alt.Chart(data, width=width)
          .mark_point(size = 120,
                      stroke = 'black',
                      strokeWidth = 2,
                      filled=True)
          .encode(
              alt.X('virus', sort = virus_order),
              alt.Y('median(titer)'),
              color = color_scheme
          )
         )
    
layered = (alt.layer(line, points)
           .facet(
               row = alt.Row('group_detail:N', sort = group_sort_list, 
                             title = None,
                             # header=None
                            ),
               config = alt.Config(
                        legend = alt.LegendConfig(titleFontSize=titleFontSize, labelFontSize = labelFontSize,
                            strokeColor='gray',padding=10,cornerRadius=10,
                            labelLimit = 1000 # Let legend labels be as long as they want
                        )
                       )
           ).configure_header(labelFontSize=labelFontSize,
                              labelFontWeight='bold',
                             labelOrient = 'top')
)

layered

# %% [markdown]
# ## Plot age cohorts

# %%
# For each cohort, 
# Plot mean titer per person across birth year cohorts
# Show the median and IQR or show all dots? Or box and whisker plots?

# %%
# Show all individual lines/titer profiles, but 
# color by age and/or facet by age in some nice way 
# Basically illustrating that age (particularly in children)
# doesn't explain neutralizing titer, particularly for those "unicorns" with the super high titers

# %%
# Initialize empty list for serum variance calculations
serum_list = []

for serum in all_titers.serum.unique(): 
    # Get titers for non-vaccine strains
    data = (all_titers[~all_titers['virus'].isin(vaccine_strains_no_Massachusetts)])

    # Get reduced dataframe of just serum in question
    serum_df = (data
              .query(f'serum == "{serum}"'))

    # Calculate serum arithmetic mean
    serum_amean = serum_df['titer'].mean()
    
    # Calculate serum geometric mean
    serum_gmean = serum_df[['titer']].apply(gmean)['titer']

    # Calculate serum median
    serum_median = serum_df['titer'].median()
    
    # Append to list
    serum_list.append([serum, serum_amean, serum_gmean, serum_median])

serum_df = pd.DataFrame(serum_list, columns = ['serum', 'serum_mean', 'serum_gmean', 'serum_median'])
all_titers_serum_aggs =  all_titers.merge(serum_df)

# %%
def plot_cohort_birth_year_means(cohort, plotWidth, title='', position=0):
    # Configure
    color_scheme = alt.Color('serum', title = 'serum', legend=None).scale(scheme='greys')
    point_color = color_palette[position]
    band_color = color_palette[position]
    titer_range = [30, 16000]
    titleFontSize=19
    labelFontSize=19
    width = plotWidth
    height = 200
    markerOpacity = 0.9


    if position == 0:
        axis_y = alt.Axis(grid=False, 
                          titleFontSize=titleFontSize, labelFontSize=labelFontSize, 
                          title=['neutralization titer'])
    elif position > 0:
        axis_y = alt.Axis(grid=False, titleFontSize=0, labelFontSize=0, title='')
        
    
    plot_x = 'year_of_birth:N'
    plot_y = 'serum_mean'
    
    # Get data
    data = all_titers_serum_aggs[all_titers_serum_aggs['group_detail'].isin([cohort])][['year_of_birth', 'serum_mean']].drop_duplicates()
    
    # Make plot
    points = (alt.Chart(data, width=width, height=height, title=title)
              .mark_point(size = 160, stroke='black', strokeWidth=2.2, filled=True,
                          color=point_color, 
                          opacity=markerOpacity)
              .encode(
                  alt.X(plot_x,
                          axis = alt.Axis(grid=False,
                                          titleFontSize=titleFontSize, labelFontSize=labelFontSize, labelAngle=270,
                                          title = 'year of birth'),),
                  alt.Y(plot_y,
                          scale = alt.Scale(type='log', domain=titer_range, nice=False), 
                          axis=axis_y),
                  # color = color_scheme
              )
             )
    
    band = (alt.Chart(data, width=width, height=height, )
            .mark_errorband(extent='iqr', color=band_color, opacity=0.4)
            .encode(
                alt.X(plot_x,),
                alt.Y(plot_y, scale =alt.Scale(type='log' ,domain=titer_range, nice=False), title=""),
            )
           ) 
    
    layered = (alt.layer(
        band, 
        points
    )
               # .properties(title=title)
               # .configure_title(fontSize=labelFontSize)
               # .facet('group_detail', columns = 1)
               # .resolve_axis(x='independent',y='independent')
               # .resolve_scale(x='independent', y='independent')
              )
    
    return layered

# %%
concat = alt.concat(plot_cohort_birth_year_means('SCH', 250, title='Children'), plot_cohort_birth_year_means('PennVaccineCohort_d0', 500, title='Pre-vaccination adults', position=1))
concat = concat.configure_title(fontSize=19)

# Save final plot
outfile = os.path.join(resultsdir, 'per_serum_means_by_birth_year.svg')
concat.save(outfile, dpi = 600)
concat
# concat.display(renderer='svg')

# %% [markdown]
# ### Plot children by age groups

# %%
# <3
# 3-8
# 10-14

age_range_list = []
for year in all_titers_serum_aggs.year_of_birth:
    if year > 2020:
        age_range_list.append('ages <3')
    elif year <= 2020 and year >= 2015:
        age_range_list.append('ages 3-8')
    elif year < 2015 and year >= 2009:
        age_range_list.append('ages 9-14')
    else:
        age_range_list.append('adult')

        
all_titers_serum_aggs['age_range'] = (age_range_list)

# %%
# Make plot with all individuals and median dots
color_scheme = alt.Color('group', 
                         title = 'Age range', 
                         # sort=group_sort_list,
                         legend=None
                        ).scale(range=color_palette)
titer_range = [30, 16000]
titleFontSize=19
labelFontSize=19
lineOpacity = 0.2
lineSize = 2.8
markerOpacity = 0.9
markerSize = 160
width = 1300
height = 200

# Get data
cohorts_to_plot = ['SCH']
data = all_titers_serum_aggs[all_titers_serum_aggs['group_detail'].isin(cohorts_to_plot)]
data = (data[~data['virus'].isin(vaccine_strains_no_Massachusetts)]
        .replace({'group_detail': group_detail_dict})
       )



line = (alt.Chart(data, width = width,height=height)
        .mark_line(size = lineSize, point = False, opacity = lineOpacity)
        .encode(
            alt.X('virus', 
                      axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                                      title = None,labelLimit = 1000, labelAlign = 'right',
                                      # labelColor = all_vacc_label_colors,labelFontWeight = all_vacc_label_weights,
                                     ),             
                      sort = virus_order
                     ),
            alt.Y('titer', 
                      scale =alt.Scale(type='log',domain=titer_range, nice=False), 
                      axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title="neutralization titer")
                 ),
            detail = 'serum',
            color = color_scheme,
            # order = 'virus_order'
        )
       )

points = (alt.Chart(data, width=width)
          .mark_point(size = markerSize,
                      stroke = 'black',
                      strokeWidth = 2.2,
                      filled=True, 
                      opacity=markerOpacity)
          .encode(
              alt.X('virus', sort = virus_order),
              alt.Y('median(titer)'),
              color = color_scheme,
          )
         )
    
layered = (alt.layer(line, points)
           .facet(
               row = alt.Row('age_range:N', sort = group_sort_list, 
                             title = None,
                             # header=None
                            ),
               config = alt.Config(
                        legend = alt.LegendConfig(titleFontSize=titleFontSize, labelFontSize = labelFontSize,
                            strokeColor='gray',padding=10,cornerRadius=10,
                            labelLimit = 1000 # Let legend labels be as long as they want
                        )
                       )
           ).configure_header(labelFontSize=labelFontSize,labelFontWeight='bold',
                              labelOrient='right', labelAngle=0, labelAnchor='start', labelAlign='right')
           .properties(title = 'Children neutralization titer profiles stratified by age range')
           .configure_title(fontSize=titleFontSize, anchor='middle')
)


# Save final plot
outfile = os.path.join(resultsdir, 'SCH_profiles_by_age_range.svg')
layered.save(outfile, dpi = 600)
layered

# %%
SCH_titers_with_metadata = (all_titers.query('group == "SCH"')
 [['group', 'serum', 'virus', 'titer', 'titer_bound', 'titer_sem',
       'n_replicates', 'titer_as', 'barcode', 'timepoint', 'year_of_birth',
       'sex', 'vaccine_2023-2024_prior_to_blood_draw',
       'days_since_most_recent_vaccination',
       'year_collected', 
       'flu_vaccine_2022-2023', 'infection_2022-2023', 'flu_vaccine_2021-2022',
       'infection_2021-2022', 'age', 'group_detail']]
 .query('days_since_most_recent_vaccination > 0')
                            .reset_index(drop=True)
)

print('these many sera had metadata...')
print(len(SCH_titers_with_metadata.serum.unique()))

# %%
print('these many sera with metadata had vaccine within 90 days...')
print(len(SCH_titers_with_metadata.query('days_since_most_recent_vaccination<=90').serum.unique()))

print('these many sera with metadata had vaccine > 90 days...')
print(len(SCH_titers_with_metadata.query('days_since_most_recent_vaccination>90').serum.unique()))

# %%
recent_vaccine_list = []
for days in SCH_titers_with_metadata.days_since_most_recent_vaccination:
    if days <= 90:
        recent_vaccine_list.append('Vaccinated w/in last 90 days')
    elif days > 90:
        recent_vaccine_list.append('Vaccinated >90 days prior')
    else:
        recent_vaccine_list.append('Something wrong happened')

        
SCH_titers_with_metadata['recent_vaccine_status'] = (recent_vaccine_list)

# %%
SCH_titers_with_metadata

# %%
# Make plot with all individuals and median dots
color_scheme = alt.Color('days_since_most_recent_vaccination', 
                         title = 'recent_vaccine_status', 
                         # sort=group_sort_list,
                         # legend=None
                        )
# .scale(range=viridis)
titer_range = [30, 16000]
titleFontSize=19
labelFontSize=19
lineOpacity = 0.2
lineSize = 2.8
markerOpacity = 0.9
markerSize = 160
width = 1300
height = 200

# Get data
data = SCH_titers_with_metadata
data = data[~data['virus'].isin(vaccine_strains_no_Massachusetts)]

line = (alt.Chart(data, width = width,height=height)
        .mark_line(size = lineSize, point = False, opacity = lineOpacity)
        .encode(
            alt.X('virus', 
                      axis = alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize,
                                      title = None,labelLimit = 1000, labelAlign = 'right',
                                      # labelColor = all_vacc_label_colors,labelFontWeight = all_vacc_label_weights,
                                     ),             
                      sort = virus_order
                     ),
            alt.Y('titer', 
                      scale =alt.Scale(type='log',domain=titer_range, nice=False), 
                      axis=alt.Axis(grid=False, titleFontSize=titleFontSize, labelFontSize=labelFontSize, title="neutralization titer")
                 ),
            detail = 'serum',
            color = color_scheme,
            tooltip = ['days_since_most_recent_vaccination']
            # order = 'virus_order'
        )
       )

# points = (alt.Chart(data, width=width)
#           .mark_point(size = markerSize,
#                       stroke = 'black',
#                       strokeWidth = 2.2,
#                       filled=True, 
#                       opacity=markerOpacity)
#           .encode(
#               alt.X('virus', sort = virus_order),
#               alt.Y('median(titer)'),
#               color = color_scheme,
#           )
#          )
    
layered = (alt.layer(line, 
                     # points
                    )
           .facet(
               row = alt.Row('recent_vaccine_status:N', sort = group_sort_list, 
                             title = None,
                             # header=None
                            ),
               config = alt.Config(
                        legend = alt.LegendConfig(titleFontSize=titleFontSize, labelFontSize = labelFontSize,
                            strokeColor='gray',padding=10,cornerRadius=10,
                            labelLimit = 1000 # Let legend labels be as long as they want
                        )
                       )
           ).configure_header(labelFontSize=labelFontSize,labelFontWeight='bold',
                              labelOrient='right', labelAngle=0, labelAnchor='start', labelAlign='right')
           .properties(title = '')
           .configure_title(fontSize=titleFontSize, anchor='middle')
)

layered
# Save final plot
# outfile = os.path.join(resultsdir, 'SCH_profiles_by_age_range.svg')
# layered.save(outfile, dpi = 600)
# layered
